# %%
import pandas as pd
import json

# %%
f = open('meld/profiles.json')
profiles = json.load(f)

# %%
for i in profiles['profiles']:
    print(i['mbti_profile'], i['personality_type'])
# Out:
# Monica Geller ESTJ 1w2
# Ross Geller ISTJ 6w5
# Chandler Bing ENTP 6w7
# Phoebe Buffay ENFP 7w8
# Joey Tribbiani ESFP 7w6
# Rachel Green ESFP 3w4
# David “The Scientist Guy“ INTP 5w6
# Carol Willick ISFJ 2w3
# Emily Waltham ESTJ 1w2
# Gavin Mitchell ENTP 8w7
# Richard Burke INFJ 2w1
# Jack Geller ESFJ 7w6
# Roger INTJ 5w4
# Judy Geller ISTJ 1w2
# Jill Green ESFP 3w4
# Pete Becker ENTJ 3w4
# Michael “Mike” Hannigan INFP 9w8
# Janice Hosenstein ESFJ 2w1
# Mr. Heckles INTP 4w5
# Mona ENFJ 9w1
# Gunther INFP 9w8
# Charlie Wheeler INTJ 5w6
# Julie ENFJ 2w1
# Ursula Buffay ISTP 3w4
# Kathy INFP 4w5
# Susan Bunch ENTJ 9w8
# Leonard Green ESTJ 8w9
# Will Colbert ISFP 9w8
# Amy Green ESFP 7w8
# Alan INFJ 9w1
# Chick "Yasmine" INTP 6w7
# Dr. Drake Ramoray ENTJ 6w5
# Phoebe Abbott ENFP 2w3
# Frank Buffay Sr. INFP 6w5
# Danny ISTP 8w7
# Gary ESTP 8w9
# Emma Geller INFP 1w9
# Joanna ESTJ 3w4
# Mr. R. Zelner ISTJ 6w5
# Bonnie ESFP 2w3
# Susie Moss ENTP 5w4
# Ugly Naked Guy ISTP 9w8
# Parker ENFP 7w6
# Tag Jones ISFP 9w1
# Ben Geller ENTP 7w8
# Nora Tyler Bing ENFJ 3w2
# Barry Farber ESTP 3w2
# Michael Tribbiani ESFP XwX
# Mark ISFJ 3w2
# The Gentleman on the Plane ISTJ 5w6
# Sandra Green ESFJ 2w1
# Frank Buffay Jr. ENFP 7w6
# Alice Knight ENFJ 2w1
# Gloria Tribbiani ESFJ XwX
# Gina Tribbiani ESFP 3w2
# Jimmy Costa ESTP 6w7
# Dina Tribbiani ESFP 7w8
# Stephen Waltham ISFP XwX
# Andrea Waltham ISFP 3w4
# Alexis Julia "Alex" Garrett ISFJ XwX
# Janine Lecroix ESFP 3w2
# Elizabeth Stevens ESFP 7w6
# Charles Bing (Helena Handbasket) ESFP 7w6
# Paolo ESTP 7w8
# Paul Stevens ISTJ 8w9
# Joshua Burgin ISFJ 6w7
# Erica ESFP 6w7
# Dr. Michael Mitchell INTP 5w6
# Fun Bobby ESFP 7w6
# Mindy Hunter ESFJ 2w3
# Estelle Leonard ESTP 7w8
# Mr. Treeger ISTJ 1w2
# Doug ESTP 3w2
# Cecilia Monroe ESTJ 3w4
# Benjamin Hobbart ENTP 3w2
# Russ ISTJ 5w6
# Eddie Menuek ISFP 6w5
# Aurora ESTP 7w8
# Tim INFJ 5w4
# Tomas ISFP 6w7
# Duck ISTP 9w8
# Melissa Warburton ISFP 2w3
# Kate Miller ESTJ XwX
# Tommy "The Screamer" ESTJ 8w7

# %%
import pickle
data = pickle.load(open(f'meld/meld.pkl','rb'))

# %%
data[3]
# Out:
# {0: ['also I was the point person on my company\x92s transition from the KL-5 to GR-6 system.',
#   'You must\x92ve had your hands full.',
#   'That I did. That I did.',
#   'So let\x92s talk a little bit about your duties.',
#   'My duties?  All right.',
#   'Now you\x92ll be heading a whole division, so you\x92ll have a lot of duties.',
#   'I see.',
#   'But there\x92ll be perhaps 30 people under you so you can dump a certain amount on them.',
#   'Good to know.',
#   'We can go into detail',
#   'No don\x92t I beg of you!',
#   'All right then, we\x92ll have a definite answer for you on Monday, but I think I can say with some confidence, you\x92ll fit in well here.',
#   'Really?!',
#   'Absolutely.  You can relax'],
#  1: ['But then who? The waitress I went out with last month?',
#   'You know? Forget it!',
#   'No-no-no-no, no! Who, who were you talking about?',
#   "No, I-I-I-I don't, I actually don't know",
#   'Ok!',
#   'All right, well...',
#   'Yeah, sure!'],
#  2: ['Hey, Mon.',
#   'Hey-hey-hey. You wanna hear something that sucks.',
#   'Do I ever.',
#   'Chris says they\x92re closing down the bar.',
#   'No way!',
#   'Yeah, apparently they\x92re turning it into some kinda coffee place.',
#   'Just coffee! Where are we gonna hang out now?',
#   'Got me.',
#   'Can I get a beer.',
#   'Hey, did you pick a roommate?',
#   'You betcha!',
#   'Is it the Italian guy?',
#   'Um-mm, yeah right!'],
#  3: ['Oh my God, oh my God! Poor Monica!',
#   'What, what, what?!',
#   'What?!',
#   'He was with her when he wrote this poem.',
#   "Look,  'My vessel so empty with nothing inside.",
#   "Now that I've touched you, you seem emptier still.'",
#   'He thinks Monica is empty, she is the empty vase!',
#   'Oh, totally. Oh, God, oh, she seemed so happy too.',
#   'Done.'],
#  4: ['Hey!',
#   'Hi!',
#   'What are you doing here?',
#   "Ah y'know, this building is on my paper route so I...",
#   'Oh.',
#   'Hi.',
#   'Hi.',
#   'How\x92d did it go?',
#   "Oh well, the woman I interviewed with was pretty tough, but y'know thank God Mark coached me, because once I started talking about the fall line, she got all happy and wouldn\x92t shut up.",
#   'I\x92m so proud of you.',
#   'Me too!',
#   'Listen, I\x92m ah, I\x92m sorry I\x92ve been so crazy and jealous and, it\x92s just that I like you a lot, so...',
#   'I know.',
#   'Yeah.',
#   'Yeah.'],
#  5: ['Ameri-can.',
#   'Ameri-ccan.',
#   "Ameri-can. Y'know it\x92s a",
#   'Everybody!!'],
#  6: ['Good job Joe! Well done! Top notch!',
#   'You liked it? You really liked it?',
#   'Oh-ho-ho, yeah!',
#   'Which part exactly?',
#   'The whole thing! Can we go?',
#   'Oh no-no-no, give me some specifics.',
#   'I love the specifics, the specifics were the best part!',
#   'Hey, what about the scene with the kangaroo? Did-did you like that part?',
#   'I was surprised to see a kangaroo in a World War I epic.',
#   'You fell asleep!!',
#   'There was no kangaroo!',
#   'They didn\x92t take any of my suggestions!',
#   'That\x92s for coming buddy.',
#   'I\x92ll see you later.',
#   'Don\x92t go!',
#   'I\x92m sorry.',
#   'I\x92m so sorry!',
#   'Look!',
#   'This guy fell asleep!',
#   'He fell asleep too!',
#   'Be mad at him!',
#   'Or, call an ambulance.'],
#  7: ['Okay, look, I think we have to tell Rachel she messed up her dessert.',
#   'What?! What is with everybody? It\x92s Thanksgiving, not...Truth-Day!'],
#  8: ['Yes, and it is my dying wish to have that ring.',
#   'See, if I\x92m not buried with that ring then my spirit is going to wander the nether world for all eternity',
#   'Okay, that\x92s enough honey!',
#   'I don\x92t know.  Let me see the ring.',
#   'Great! Okay, here.',
#   'All right.',
#   'Thank you. Thank you. Thank you!  And'],
#  9: ["What've you been up to?",
#   'Oh, you know, the usual, teaching aerobics, partying way too much.',
#   'Oh, and in case you were wondering, those are my legs on the new James Bond poster.',
#   'Can you hold on a moment? I have another call.  I love her.',
#   'I know.',
#   "I'm back.",
#   'So, are we gonna get together or what?',
#   "Um, absolutely. Uh, how 'bout tomorrow afternoon? Do you know uh, Central Perk in the Village, say, five-ish?",
#   "Great, I'll see you then.",
#   'Ok.  Ok. Having a phone has finally paid off.',
#   'Even though you do do a good Bob impression, I\'m thinkin\' when she sees you tomorow, she\'s probably gonna realize, "Hey, you\'re not Bob."',
#   "I'm hoping that when Bob doesn't show up, she will seek comfort in the open arms of the wry stranger at the next table.",
#   'Oh my god. You are pure evil.',
#   "Ok, pure evil , horny and alone . I've done this"],
#  10: ['Nobody!',
#   'Nobody respects the bucket!',
#   "You wouldn't believe what people put in here!",
#   'Look!',
#   'Okay, does this look like a garbage can to you?',
#   'No.'],
#  11: ['This is my wedding.',
#   'All right, y\x92know what? We really are late! Let\x92s go! Let\x92s go! Let\x92s go!!',
#   'Fine. You\x92ll-you\x92ll watch it on video when we get back.',
#   'Here you go Phoebe! Here you go Phobo! Phewbedo! Phaybobo.',
#   'Thank you.',
#   'Thank you.',
#   'All right, let\x92s go! Bye, Pheebs!',
#   'Bye, Pheebs!',
#   'London baby!!',
#   'Oh, do you need a hug? You don\x92t have to bring me anything!'],
#  12: ['Hey!',
#   'Hey! So Estelle lined up a bunch of auditions for me tomorrow and I\x92ll have my health insurance back in no time.',
#   'That\x92s great, but shouldn\x92t you be on the toilet right now?',
#   'What?!',
#   'What\x92s wrong with you?',
#   'Nothing!',
#   'Well, I-I got this blinding pain in my stomach when I was lifting weights before, then I uh passed out and uh, haven\x92t been able to stand up since.',
#   'But um, I don\x92t think it\x92s anything serious.',
#   'This sounds like a hernia. You have to\x97you-you go to the doctor!',
#   'No way! \x91Kay look, if I have to go to the doctor for anything it\x92s gonna be for this thing sticking out of my stomach!',
#   'That\x92s a hernia.',
#   'Why did I have to start working out again?  Damn you 15s!'],
#  13: ['I love your place! Where is this guy from?',
#   'Uh that\x92s an eighteenth century Indian artifact from Calcutta.',
#   'Oh wow! So, you\x92re more than just dinosaurs.',
#   'So much more.'],
#  14: ['Well, well to sum up, we\x92re having fun, you look young.',
#   'Okay',
#   'But that\x92s not enough. So\x85 So\x85here\x92s a key to my apartment.',
#   'Really?!',
#   'Really.',
#   'You don\x92t think this is too fast.'],
#  15: ['Get Out!',
#   'Ross, can I talk to you for a minute?',
#   "Yes, please!  So, what's going on?",
#   'Uh, well... Joey and I broke up.',
#   'Oh my God, wh-what happened?',
#   "Joey is a great guy, but we're just... so different! I mean, during your speech he kept laughing at homo erectus!",
#   'I knew that was him!',
#   "Anyway I just, uh, I think it's for the best.",
#   'Hey, you ok?',
#   'I guess.',
#   'There was hum...  there was another reason that I thought it was time to end it with Joey.',
#   'I started to realize that I was having feelings for someone  else.',
#   'Ok Geller. Last day of the conference, you know what happens to the keynote speaker.',
#   "Oh, professor Clerk we're kind of in the middle of a conversation, here.",
#   'Yeah, can you guys just throw him in the pool later?',
#   'Or we could throw you both in',
#   'Ok, gentlemen!',
#   'Please!',
#   "Aren't we a little old for this?",
#   "I mean, we're scientists, right?",
#   "We're academics.",
#   'And most importantly I... you-you will have to catch us first.',
#   'GO, GO, GO!'],
#  16: ['Go, go, go!',
#   'Oh yeah, now everybody wants to be under this hat!',
#   'Oy!!',
#   'What\x92s with all this sand?',
#   'Oh, yeah, Bob said there might be flood damage.',
#   'Yeah, either that, or he has a really big cat.'],
#  17: ["Okay, see that blind guy right there? I'm gonna bash his head in later.",
#   'Oh umm, my big scene is coming up. Big scene coming up.',
#   'If you said, "Big lima bean, bubbling up." Would she understand the difference?',
#   'Rach? What are you doing?',
#   "Oh boy, I just can't watch. It's too scary!",
#   "It's a diaper commercial.",
#   'Oh yeah well, you know me, babies, responsibilities, ahhh!!!',
#   'Pizza delivery!',
#   "I'll get it! I will get that!",
#   'Hi!',
#   'Hi!'],
#  18: ['Hey, you wanna get something to eat or uh, do you wanna see how long we can throw this ball back and forth? Huh?',
#   'Uhh, the ball thing.',
#   'Yeah?',
#   "Hey Ross, wouldn't it be great if we could go two straight hours without dropping it?!",
#   'Uhh,',
#   'Okay!',
#   'Uh-oh.',
#   'What?',
#   "I have to pee. And Rachel's in the bathroom!",
#   "Man, I didn't think we were gonna make it!",
#   "I know!  Don't switch hands, okay?"],
#  19: ['Hey.', 'Hey!'],
#  20: ['How did it go with Erin?',
#   'Oh, unbelievable! We had the best time!',
#   'Yay!! Oh so, you\x92re not, you\x92re not mad at us anymore?',
#   'No!',
#   'No!',
#   'No!',
#   'You guys were totally right!',
#   'This is so much better than the first time we went out.',
#   'Y\x92know?',
#   'That was so awkward, we were really nervous.',
#   'Didn\x92t you sleep together?',
#   'Yeah, that really calms me down.',
#   'And!',
#   'We have so much in common!',
#   'She loves sandwiches, sports, although she is a Met fan, not much of an issue now but if we were ever to have kids, well that\x92s a',
#   'Oh my God! Listen to you talkin\x92 about having kids. Oh my Joey.  Oh, please don\x92t get married before I do.',
#   'Okay.'],
#  21: ['How does she do that?',
#   'I cannot sleep in a public place.',
#   'Would you look at her? She is so peaceful.',
#   'Oh! What what what! ...Hi.',
#   "It's okay, y'know, you just nodded off again.",
#   "What's going on with you?",
#   'I got no sleep last night!',
#   'Why?',
#   "My grandmother has this new boyfriend, and they're both kind of insecure in bed.",
#   'Oh, and deaf.',
#   "So they're constantly, like, having to reassure each other that they're having a good time.",
#   'You have no idea how loud they are!',
#   'Well, if you want, you can stay with Rachel and me tonight.',
#   'Thanks.'],
#  22: ['Ew! What is that? Something exploded!',
#   "It's just her water breaking. Calm down, will you?",
#   "Water breaking, what do you mean? What's that, water breaking?",
#   'Breathe, breathe, breathe.'],
#  23: ['Are you insane? I mean Joey, is going to kill you, he\x92s actually going to kill you dead.',
#   'Okay! You don\x92t think I thought of that?',
#   'How can you not know which one?',
#   'I mean that\x92s unbelievable.',
#   'I mean, was it Gina?',
#   'Which one is Gina?',
#   'Dark, big hair, with the airplane earrings.',
#   'No, no, no, that\x92s Dina.',
#   'You see you can\x92t tell which one is which either, dwha!!'],
#  24: ['I don\x92t know, you thought \x91See you Saturday\x92 was funny.',
#   'Look honey, Mark is in fashion okay, I like having a friend that I can share this stuff with.',
#   'You guys would never want to go to a lecture with me.',
#   'Pa-haa!! I would love to go with you.',
#   'Really!?',
#   'Yeah, hey I-I have clothes, I even pick them out.',
#   'I mean for, for all you know I could be a fashion..... monger.',
#   'Okay. Honey, I would love for you to go with me.  What?',
#   'What should I wear, now I\x92m all nervous.'],
#  25: [': I know, we did it!! Hey, that was incredible, huh?!',
#   'I know, it was amazing! I mean, we totally nailed it, it was beautiful.',
#   ': Thank you, listen, thanks a lot Tribbiani, . Oh my God, look at the time, I gotta catch the bus to the ball.',
#   'Oh well, okay, good luck.',
#   ': Yeah.',
#   'Unless you wanna practice the Foxtrot again? Or-or the Tango?',
#   ': Ahh, thanks but no. You see I-I think I\x92m ready to dance with girls.',
#   'Okay.',
#   ': Yeah.',
#   'Go get \x91em Treeger.',
#   ': Right.  Hey, ahh, you wanna come? Marge has a girlfriend.',
#   'Really?',
#   ': Yeah, you could dance real good with her, she\x92s the same size as me.',
#   'No, I\x92m good.'],
#  26: ['Oh God, this is so nerve wracking! How-how do you do this?',
#   "Well, unfortunately, I don't get many callbacks so",
#   'Is it a good sign that they asked us to hang around after the audition?',
#   'Who knows?',
#   'Okay uh, we have narrowed it down to Raymond, Ben, Kyle, and Joey. The rest of you, thank you very much.',
#   'Yes!! I knew it!!  Bye-bye! So long! Later!',
#   "Oh this is great! I might actually get to play Ben's dad!",
#   'Yeah!',
#   "Actually, that can't happen.",
#   "Yeah because you all have such different looks, we're putting you with Raymond and Kyle with Ben.",
#   "So it'll be either you two  or you two.",
#   'Man, this is gonna be kinda weird.',
#   'Yeah, it is.',
#   "No, we-we're gonna be like best friends, that's why it's gonna be weird."],
#  27: ["Okay, come on, I can't get married until I get something old, something new, something borrowed, and something blue.",
#   "Okay, all right, all right, all right! Okay!  Okay, here's something, here's something blue and new."],
#  28: ['Please!',
#   'Are you kidding?',
#   'I-I hurt three huge men, I gave a guy a bloody nose\x97I mean I-I\x92m not proud of it but, I really am.',
#   'And it\x92s all because of you, wonderful, amazing you.',
#   'I think you\x92ve got concussion.',
#   'No, no, I\x92m serious. Thank you.',
#   'You\x92re welcome.  I\x92m sorry. Did I hurt you?',
#   'It\x92s worth the pain.  Y\x92know what, you know what? It\x92s not.'],
#  29: ["Wow! That Mike thing was interesting! I don't know what's gonna happen with Phoebe and David.",
#   'I do! Want a hint? huh? "I do"  "I do".',
#   "Ok, I'm sensing that this is some kind of word play, because you are pink with barely controlled glee.",
#   'David is going to propose to Phoebe.',
#   'What?  Why?',
#   'Chandler, we have talked about this.',
#   'You are not supposed to give people advice!',
#   "Now couldn't you just have made some sort of inappropriate joke?",
#   'I',
#   "They've only been going out for a few weeks and Phoebe is completely hung up on Mike!",
#   'She\'ll say "No", David\'s heart will be broken, it will be too hard for them to recover from and then Phoebe will end up alone',
#   "Man, that's some",
#   "Oh, that's not what you want..."],
#  30: ['This is my father, Paul Stevens. Dad, this is Ross Geller.',
#   'It-it\x92s great to meet you Paul.',
#   'I usually prefer Elizabeth\x92s boyfriends to address me as Mr. Stevens.',
#   'Of course, of course, Mr. Stevens.',
#   'So Ross, what your problem?',
#   'Eh-wh\x97Excuse me?',
#   'Why can\x92t you get a girlfriend your own age?',
#   'That\x92s funny. Umm\x85.  It\x92s not funny.',
#   'I',
#   'Okay.',
#   'I can, I can see that.',
#   'Umm, but I think if you give me umm, one chance I can, I can change your mind.',
#   'Okay.',
#   'What?',
#   'Okay. I\x92ll give you one chance to change my mind.  You got one minute.',
#   'Daddy!'],
#  31: ['Oh well, it\x92s not on TV yet.',
#   'Well, then it\x92s not on the wall yet.',
#   'Okay, fine, I will bring you a tape, huh?',
#   'So umm, now do you have any of Matt Lauer\x92s clothes here? Maybe? Just ones that haven\x92t been cleaned yet?'],
#  32: ['Ooooohh!',
#   "Oh yeah, I'm sure.  And all of a sudden his hands weren't the problem anymore.",
#   'Was it...?',
#   'Oh, boy scouts could have camped under there.',
#   '"Ooo," what?',
#   'Uma Thurman.',
#   'Oh!',
#   'The actress!',
#   'Thanks Rach.',
#   'So what are you gonna do?',
#   'You have to tell her!',
#   'You have to tell her!',
#   "It's your moral obligation, as a friend, as a woman, I think it's a feminist issue!",
#   'Guys?',
#   'Guys?',
#   'Oh, yeah, you have to tell her.',
#   "Feminist issue. That's where I went!",
#   'She is gonna hate me.',
#   'Yeah, well...'],
#  33: ['Will you marry me?',
#   'It\x92s the big night! We wanted to wish you good luck!',
#   'Yeah, yeah you have the ring?',
#   'Yeah, right here in my pocket.  Pheebs?',
#   'Oh! Oop!',
#   'Okay, now will you guys get out of here? I want this is to be a surprise and she\x92s gonna know.',
#   'Yeah-yeah you guys. Get out of here!',
#   'Hi guys.',
#   'You are beautiful.',
#   'Oh, thank you!   What\x92s going on?',
#   'We\x92re just really\x85very excited about this charity event that we have to go to.'],
#  34: ['Okay umm, Ross?',
#   "I'm-I'm really warm, so I'm going to be taking off my sweater.",
#   "Now, I'm just letting you know that this is",
#   "Yep! That's hilarious!",
#   "I'm sorry. I'm done. I'm done.",
#   "Y'know, last night was embarrassing for you too.",
#   "No, not really. I mean you've seen me naked hundreds of times.",
#   'Uh-huh. But it was a first for the rest of my building.',
#   "Okay. All right, that's true! But y'know I just don't embarrass that easily.",
#   'What?! You totally get embarrassed!',
#   "No, I don't! Ross, I think I'm just a more secure person than you are.",
#   'Is that so?',
#   'Yeah.',
#   "Hey lady! I don't care how much you want it! Okay?! I am"],
#  35: ['I can\x92t believe it!',
#   'I did it!',
#   'I rode a bike!',
#   'I never thought I\x92d be able to do that!',
#   'Thank you Ross.',
#   'Oh hey, don\x92t thank me, thank yourself. You\x92re the one who faced her fears and ultimately overcame them.'],
#  36: ['Hey, both you guys should be up there with me.',
#   'I mean, you two are-are my\x85 I mean, I\x92m lucky to have just one good',
#   'Thanks man.',
#   'I gotta go check something over here.',
#   'What a baby.',
#   'Total wuss!'],
#  37: ['Okay, we have a lot of options here, a number of prototypes for you to try on.',
#   'Wow! This looks great!',
#   'Yeah! Okay, this one is a mushroom cap.  Umm, this one is made of bologna.',
#   'And-and-and-and-and the toothpicks?'],
#  38: ['You kissed another woman!',
#   'Call it even?!',
#   'Okay!',
#   'Well, I\x92m gonna go get these  in some water.',
#   'Wait you stole those from these people\x92s wedding?',
#   'No-no, I took them from the hotel lobby.',
#   'Yeah, they think they can charge me for some dirty movie and a bag of Mashuga nuts, they got another think coming.',
#   'Hey!',
#   'My sweater!',
#   'I\x92ve been looking for this for like a month!',
#   'Oh my God!!',
#   'Oh my God!'],
#  39: ['Happy?! Is that what I\x92m supposed to be Vic? Happy?',
#   'Well, why don\x92t you tell me what you\x92re supposed to be!',
#   'Huh?',
#   'Because I sure as hell can\x92t figure it out!',
#   'I talk to you and nothin\x92.',
#   'You look at me, and it\x92s nothin\x92.',
#   'Nothing.',
#   'Tasty! I\x92m really starting to feel like you guys have a history, it\x92s-it\x92s nice.',
#   'I have a question about this scene.',
#   'Yes?',
#   'Well, I don\x92t understand why Adrienne\x92s attracted to Victor.',
#   'Peel the onion. First of all, he\x92s good looking.',
#   'Yeah.',
#   'I think my character\x92s gonna need a little bit more of reason than that.',
#   'Oh, hey, how about this one.',
#   'Ah, it\x92s says so in the script!',
#   "Y'know ah, I-I don\x92t know why my character likes you either, I mean it says in the script here that you\x92re a bitch.",
#   'It doesn\x92t say that in the script.',
#   'It does in mine!'],
#  40: ['I can\x92t',
#   'Yeah! You gotta tell a girl before you tape her. Such a rookie mistake.',
#   'Y\x92know who has a great video camera?',
#   'Greg and Jenny?',
#   'Do you still wanna call \x91em? I wanna call \x91em.',
#   'Let\x92s call \x91em.',
#   'Yeah! Ask them if they brought their friends any souvenirs!',
#   'Hello?  Eighth street deli?',
#   'Hey, hang up! You get food poisoning just talkin\x92 to that place.',
#   'Uh sorry, wrong number.',
#   'Here you go.',
#   'Hello?   It\x92s the deli again!',
#   'All right! I\x92ll have a sandwich!',
#   'I don\x92t think this number\x92s right!',
#   'Oh come on!!'],
#  41: ["Gotta go. I miss you too, I love you, but it's getting real late now",
#   "Hey Ma. Listen, I made the appointment with Dr. Bazida, and... Excuse me?  Did you know this isn't Ma?",
#   "Her name's Ronni. She's a pet mortician.",
#   'Sure. So how long you been...',
#   'Remember when you were a little kid, I used to take you to the navy yard and show you the big ships?',
#   'Since then?!',
#   "No, it's only been six years.",
#   "I just wanted to put a nice memory in your head so you'd know that I wasn't always such a terrible guy.",
#   '...Joe.',
#   "Y'ever been in love?",
#   "...I d'know.",
#   "Then y'haven't. You're burning your tomatoes.",
#   "You're one to talk.",
#   "Joe, your dad's in love big time. And the worst part of it is, it's with two different women.",
#   "Oh man. Please tell me one of 'em is Ma.",
#   "Of course, course one of 'em's Ma. What's the matter with you."],
#  42: ['Everything\x92s gonna be all right. Okay, Dick?',
#   'Hello, I am Guru Saj--Whoa!!  That\x92s supposed to be a duck right? \x91Cause otherwise, this is waaay out of my league.'],
#  43: ['Hey, Rach, how was work?',
#   'Oh, great. Although I did sit down where there wasn\x92t a chair.',
#   'By the way, Ross dropped by a box of your stuff.',
#   'Oh, well, I guess I had that one coming.',
#   'I\x92m just gonna throw it out, it\x92s probably just a bunch of shampoo and...',
#   'Something wrong?',
#   'No. Nothing.'],
#  44: ['And then, and then you said that thing about, about bringing the Mesozoic era in the 21st century.',
#   "Yeah, that's it?",
#   'Yeah.'],
#  45: ['Dude, I am sorry about what I said!',
#   'No, no, you\x92re right, it is a ridiculous name!',
#   'It\x92s not that bad.',
#   'Yes it is! From now on, I have no first name.',
#   'So, you\x92re just Bing?'],
#  46: ['Because we won our apartment back!',
#   'What? Ace is high! Jack, queen, king, ace!',
#   'No! Ace is low! Ace, two, three, four!',
#   'I don\x92t know. Ooh! Ooh! Look it!  Ah-ha!',
#   'All right, cut, let\x92s pick again, pick again.',
#   'Okay.',
#   'Come on apartment! Come on apartment!  Oh! I know queen is high!',
#   'Uh-huh, not as high as\x85 It worked! King!',
#   'Yeah baby!',
#   'But, we pick again! We pick again!',
#   'Why?!',
#   'I don\x92t know!',
#   'Tickets please!  That\x92s courtside baby!',
#   'Seriously, good game though. Good game.   What are they so mad about? They get the apartment back!',
#   'No they didn\x92t!'],
#  47: ["You know, I don't think we brought enough stuff. Did you forget to pack the baby's anvil?",
#   "It's gonna be worth it.",
#   "It's a known fact that women love babies, all right?",
#   'Women love guys who love babies.',
#   "It's that whole sensitive thing.",
#   "Quick, aim him at that pack o' babes over there.",
#   'Maybe one of them will break away.',
#   'No, no wait, for get them, we got one, hard left.',
#   'All right, gimme the baby.',
#   'No, I got him.',
#   'Oh, seriously you want him?',
#   'Hello.',
#   "Well, don't, don't think me immodest, but, me?",
#   'You wanna smell him?',
#   "Oh, yeah. He's got that great baby smell. Get a whiff of his head.",
#   "What'd I tell you? What'd I tell you?",
#   'Well, we are great guys.'],
#  48: ['Bye.'],
#  49: ['Well, not really.',
#   'I mean technically it\x92s-it\x92s not against the rules or anything, but it is frowned upon.',
#   'Especially by that professor we ran into last night, Judgey von Holierthanthou.',
#   'Well Ross, you be careful now. You don\x92t want to get a reputation as y\x92know Professor McNailshisstudents.',
#   'Yeah. What-what should I do?',
#   'Well Ross, it seems pretty clear.',
#   'I mean what\x92s more important?',
#   'What people think or how you feel, huh?',
#   'Ross, you gotta follow your heart.',
#   'Joey that is so sweet.',
#   'Hey.',
#   'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'I couldn\x92t do it.',
#   'You couldn\x92t do it?!',
#   'Hey, relax I just need more time. We\x92re going to dinner tonight.',
#   'What?! You\x92re going out with her again!',
#   'Going out with who?',
#   'Uh, Dana Keystone from college.',
#   'Oh yeah! Wasn\x92t she uh',
#   'No, that was Dana Caplin.',
#   'Joey! You didn\x92t even know her!',
#   'Ah whatever!'],
#  50: ['Morning! Hey, how\x92s my favorite genius and my little robot buddy?!',
#   'Don\x92t touch him!',
#   'Okay!',
#   'All right.',
#   'Umm, all right Wayne, level with me.',
#   'I-I keep hearing all these rumors that I might get fired.',
#   'Okay, they even have actors coming in to read for my part!',
#   'Come on man, you-you got to give me a second chance!',
#   'I mean, I love-I love this little guy!',
#   'Ah-ah!!',
#   'Okay, that\x92s why you didn\x92t want me to touch him right?',
#   'Here you go!',
#   'Okay?',
#   'Stupid!',
#   'I can\x92t believe it!',
#   'God!',
#   'Hey, how you doin\x92?'],
#  51: ['Hey.',
#   'Hi. Look um, about what happened earlier...',
#   'No, hey, well, I-I completely understand. You were, you were stressed.',
#   'I was gonna give you a chance to apologise to me.',
#   'For what? For letting you throw me out of your office?',
#   'You had no',
#   'Yeah, well excuse me for wanting to be with my girlfriend on our anniversary, boy what an ass am I.',
#   'But I told you, I didn\x92t have the time!',
#   'Yeah, well you never have the time. I mean, I don\x92t feel like I even have a girlfriend anymore, Rachel.',
#   'Wh, Ross what do you want from me?',
#   'You want me, you want me to quit my job so you can feel like you have a girlfriend?'],
#  52: ['I know.',
#   'Ooh, I have to tell you something.',
#   'What?',
#   'But I can\x92t tell you.',
#   'Okay, but wouldn\x92t it be easier if you had to tell me something that you could tell me.',
#   'Well, sure in a perfect world. But, no, I promised I wouldn\x92t tell, and I swore to like all my gods.',
#   'Okay. Does it have to do with Ross and Rachel?',
#   'No.',
#   'Does it have to do with Joey?',
#   'No.',
#   'Does it have to do with-with Chandler and that sock that he keeps by his bed?',
#   'No, but let\x92s come back to that later!'],
#  53: ['Hi!',
#   'Richard!',
#   'Actually, I\x92m not here to complement the chef.',
#   'Ohh\x85 Oh, that\x92s okay I hate when people come back to complement the chef.',
#   'Like I have nothing better to do!',
#   'So what\x92s up?',
#   'Well, it was great seeing you the other night.',
#   'Oh, good to see you too. Did you come down here to tell me that?',
#   'No! I came here to tell you something else.  I came here  to tell you I still love you.'],
#  54: ['One pregnant woman at a time, please! I just want you to be okay.',
#   'So forcing her to marry Bobby is gonna make that happen?',
#   'Maybe!  Well! Well\x85so-so uh, what kind of music does Numb Nuts\x97Oh forget it! I can\x92t!',
#   'Joey, I am scared to death about this.',
#   'But I really think I can do it, I\x92m just gonna need some help.',
#   'And Bobby\x92s gonna be here the whole time.',
#   'You bet I am!  And to answer your earlier question, we\x92re straight-up gangster rap.',
#   'Look, Rachel\x92s told me how much easier you\x92ve made all this on her. Why can\x92t you do that for me?',
#   'Because! \x91Cause\x85 \x91Cause you\x92re my baby sister!',
#   'And you\x92re my big brother!',
#   'I mean, you\x92re my favorite guy in the whole world.',
#   'I\x92m not even scared to tell mom and dad.',
#   'I was scared of telling you.',
#   'Well I\x92d be scared of them, but all right.',
#   'Joey, I can\x92t stand the thought of having this baby with you mad at me.',
#   'I want him to have his uncle.',
#   'Is my baby gonna have his Uncle Joey?',
#   'Of course he\x92s gonna have his Uncle Joey!',
#   'We\x92re gonna be all right. I mean, even if we\x92re not married this baby is gonna be so loved. Not just by us.',
#   'That\x92s right! By his uncle too!',
#   'And by you.',
#   'Okay Bobby, why don\x92t we just come over here and let them have a little moment.',
#   'Come here!',
#   'No! Seriously! What\x92s wrong with you?!'],
#  55: ['I had a really nice time tonight.',
#   "So did I. I'm really glad Monica asked us out.",
#   "I'd love to ask you in, but uh, my sister's visiting and I think she's asleep on the couch.",
#   "You're sister? You're sister's asleep on the couch?  Ohhh! I saw",
#   "Oh hey, great, you're up. Rachel, this is my sister Krista. Krista, this is Rachel.",
#   'Hi!',
#   "Nice to meet you. I wish you'd told me we were having company, I'd fix myself up!",
#   'Like it would help.',
#   'You are so bad!',
#   'You are!',
#   'You are!',
#   'You are!',
#   'You are!',
#   'You are!',
#   'You are!',
#   "You are so dead! I'm gonna get you.",
#   'Uh, it was very nice meeting you.'],
#  56: ["Oh my God, it's that Victoria's Secret model. Something... something Goodacre.",
#   "Hi Mom, it's Jill.",
#   "She's right, it's Jill. Jill Goodacre. Oh my God. I am trapped in an ATM vestibule with Jill Goodacre!",
#   "Yeah, I'm fine. I'm just stuck at the bank, in an ATM vestibule.",
#   "Jill says vestibule... I'm going with vestibule.",
#   "I'm fine. No, I'm not alone... I don't know, some guy.",
#   "Oh! Some guy. Some guy. 'Hey Jill, I saw you with some guy last night. Yes, he was"],
#  57: ['Are you seeing anybody right now?',
#   'Og-ee-op, I\x92m not asking for me, I\x92m\x85 I mean\x85 No, I\x92m-I\x92m not gay, I\x92m not asking you out.',
#   'I\x92m not-I\x92m not-I\x92m not gay!'],
#  58: ['Personal shopping? What is that? Like where you walk around with snooty rich people and tell them what to buy?',
#   'Uh-huh.',
#   'That sounds great!',
#   'Hey!',
#   'Umm, excuse me, we switched apartments. You can\x92t eat are food anymore, that-that gravy train had ended.',
#   'There\x92s gravy?',
#   'If you have the big apartment you have to deal with people coming over all the time.',
#   'That fridge has got to be stocked, okay, that\x92s your department now.',
#   'What are you doing?',
#   'I think I left a donut up here.'],
#  59: ['So, in conclusion, the lines all go up , so I\x92m happy.',
#   'Great job team!',
#   'Tomorrow at 8:30.',
#   'Phil!',
#   'Nice job.',
#   'Stevens!',
#   'Way to go!',
#   'Joel-burg, you maniac!',
#   'I love ya!',
#   'Bing!'],
#  61: ["Oh, excuse me. I forgot my briefcase y'know, by accident.",
#   'Of course, you did.',
#   'Forgot something else too ya bastard!',
#   'Well, what about you?',
#   'You\x92re not feeling left out or anything are ya?',
#   'No. No, not at all, that\x92s-that\x92s ridiculous.',
#   'Everybody else got one, and you want one too. Don\x92t you?',
#   'Ye-ye-yeah, yes I do!',
#   'Now get on out of here, you!'],
#  62: ['Hey Bob.',
#   'Hey! How\x92s my pal Toby doing today?',
#   'If I see him, I\x92ll ask.',
#   'Toby!',
#   'Yeah!',
#   'Oh then you know each other.',
#   'We\x92re on a semi-first name basis.',
#   'What do you think of adding him to our team?',
#   'Bob? Ooh, working here with us? Everyday? Yeah, I don\x92t know if he has what it takes.',
#   'Really? They love him down on six.',
#   'But this is eleven. It\x92s almost twice as hard up here.'],
#  63: ['Hey! Guess what I got for your wedding!',
#   'A freakish thin date with a hanger for her head?',
#   'No. Rachel hooked me up with a tux! But not just any tux, Batman\x92s tux!',
#   'What?',
#   'That\x92s right! Made expressly for Val Kilmer and worn by him in the hit film\x85that Batman film he was in.',
#   'You can\x92t wear that! I\x92m wearing the famous tux! James Bond\x92s tux!',
#   'So?',
#   'So\x97If you wear that you\x92ll make mine less special.'],
#  64: ['Sorry, I just don\x92t like the idea of when I say "I do," he\x92s thinking, "Yeah, I\x92d do her too!"',
#   'Well then we still have a problem.',
#   'Yeah!',
#   'With what?',
#   'Well, we\x92re trying to find someone to perform our wedding and they\x92re all either boring or annoying or y\x92know, can\x92t stop staring at the ladies.',
#   'Oo! You should have one of us do it!',
#   'Phoebe, we\x92re getting',
#   'No! No! It\x92s-it\x92s uh a real thing! Anyone can get ordained on the Internet and perform like weddings and stuff!',
#   'I call it!!',
#   'What?! No! It was my idea!',
#   'Guys thank you very much but neither of you is marrying us.',
#   'Does calling it not mean anything anymore?!',
#   'We are going to have a legitimate member of the clergy! And when I say legitimate I mean, gay and in control of his saliva!'],
#  65: ['See, I see.... big passion in your future.',
#   'Really?',
#   'I do.',
#   "Oh Ross, you're so great. [she playfully rubs his head and gets up]"],
#  66: ['That was supposed to be a good thing, I forget why.',
#   'Just listen, Monica, I, do you know, okay, do you know, I couldn\x92t sleep for like a month because I got like a dot of ink on one of the sofa cushions.',
#   'Well, you-you coulda just turned the cushion over.',
#   'Yeah, I would\x92ve except I had a big spaghetti stain on the other side.',
#   'What?!?!',
#   'Okay, this is what I\x92m talking about, this. I-I need to live in a land where people can spill.',
#   'You can spill. In the sink.',
#   "Aw, honey it\x92s not your fault, y'know this is who you are, and I love you, and I want us to be friends, and if I keep living here I don\x92t see that happening.",
#   'I love you, too.',
#   'Aww, good.  What?',
#   'What? I\x92m just said.',
#   'No you\x92re not, you\x92re wondering which cushion it is.'],
#  67: ['Oh my God! Are you serious?!',
#   'Uh-huh.',
#   'I would love to live with you Ross.. that\x92s-that\x92s great! Thank you!',
#   'Well, I\x92m-I\x92m just glad I could, y\x92know, help you out.',
#   'Ross-Ross, you have no idea what this means to me!',
#   'I mean, I mean I was gonna be homeless.',
#   'You just saved me!',
#   'You\x92re my hero!',
#   'Hero, I uh, I don\x92t know\x97well, all right.',
#   'Oh, I have to go tell Monica what a wonderful brother she has!',
#   'Oh please!   You\x92re gonna say things now, aren\x92t ya?',
#   'No.',
#   'No, I won\x92t.',
#   'But I should tell you this, this exact same thing happened to my roommate Denise.',
#   'She moved in with a guy who was secretly married to her and he said he didn\x92t love her, but he really did, and it just blew up!'],
#  68: ['...Dammit, hire the girl!  Okay, everybody ready?',
#   'Uh, listen, I just wanna thank you for this great opportunity.',
#   'Lose the robe.',
#   'Me?'],
#  69: ["That's great.",
#   "Well, I'm gonna get another espresso. Can I get you another latte?",
#   "No, no, I'm still working on mine.",
#   "That's it?",
#   'Yeah, it was really hard.',
#   'Oh, yeah, that hug looked pretty brutal.',
#   "Ok, you weren't there."],
#  70: ['Wow! That\x92s ah, that\x92s pretty nice!',
#   'Pretty nice?',
#   'You\x92ll have to pardon my roommate, he wanted to marry this.',
#   'We don\x92t have 50 bucks, but would you be willing to trade for it? We\x92ve got a canoe.',
#   "Y'know, I, I really don\x92t think we need a canoe.",
#   'You gotta take the canoe!',
#   'All right, just, just take the entertainment center, and then when you get home, throw the canoe away!',
#   'We\x92re not throwing it away! I built that canoe!',
#   'Good for you!!'],
#  71: ['Pheebs?', 'Yeah?'],
#  72: ['Okay. Then I guess it\x92s just, wait here then.   Hi. I need one fake ticket to Yemen.',
#   'One ticket to Yemen?',
#   'Oh no-no-no, no. No, no, no, I just, I just need a pretend ticket.',
#   'I\x92m sorry sir, I don\x92t understand.',
#   'What would you give to a kid if he wanted a ticket to play with?',
#   'Are you travelling with a child?',
#   'No.',
#   'All right, y\x92know what, she\x92s  gonna think that I\x92m handing you a credit card, but what I\x92m really gonna do is hand you a library card.'],
#  73: ['Okay, but this is the last time.',
#   'With a chick-chick here, and a chick-chick there.',
#   'Here a chick, there a chick, everywhere a chick-chick--chickeeeen.',
#   'Hey.',
#   'Hey.',
#   'How\x92s she doing?',
#   'She?',
#   'Well yeah, don\x92t-don\x92t you think it\x92s a she?',
#   'I don\x92t know.  I can\x92t tell, what ever it was went back in too quickly.',
#   'Well, anyway, I got to go change, I\x92m ah, meeting some of the cast for drinks.',
#   'Excuse me?',
#   'What?'],
#  74: ['Okay, good, so there you go. Go with Vince.',
#   "Yeah, but Jason's really sensitive.",
#   'Well sensitive is important, pick him.',
#   'Yeah.',
#   'Oh sure, go with the sissy.',
#   'Jason is not a sissy!',
#   'Oh no-no-no-no, I meant Chandler.'],
#  75: ['Hi.'],
#  76: ['So uh, apparently people are familiar with the Europe story?',
#   'Yeah.',
#   'Listen about that, the whole uh, who came on to who thing really doesn\x92t matter.',
#   'I mean, I think it would\x92ve happened either way.',
#   'I mean if you hadn\x92t initiated it I-I-I know I would\x92ve.',
#   'It was an amazing night.',
#   'It was. It was an amazing night.',
#   'You think it looked amazing?'],
#  77: ['Do we have a name yet?',
#   'No, not yet.',
#   'That\x92s fine, for now we\x92ll just call her Baby Girl Green.',
#   'Oh no, Baby Girl Geller-Green.',
#   'Hello baby girl.'],
#  78: ['Ah-ha, nowhere to run!',
#   'I don\x92t like sitting up here! I\x92m just gonna over',
#   'No Rachel! They got here first!',
#   'Why is Ross doing that?',
#   'DANGER',
#   'Oh my God! Why is he jumping on those women!'],
#  79: ['No that\x92s all right. Don\x92t worry about it.',
#   'Oh but look! That\x92s gonna leave a stain!',
#   'Rach! Hey! It\x92s fine! You\x92re at Joey\x92s!',
#   'Really?',
#   'Yeah! Look!',
#   'I\x92ve never lived like this before.',
#   'I know.',
#   'All right, don\x92t waste it, I mean its still food.'],
#  80: ['Hey Joey, is this the bed where Olivia lost her virginity?',
#   "I don't know, but one of the extras sure did!  Hey, listen    Rach. Thanks again for coming down to watch my scenes!",
#   "Oh, please!Honey, just the fact that you want me here to support    you, I'm...OH MY GOD!Is that Christian Sanders?He's so",
#   'Also so',
#   'Oh, in my head he\'s done some pretty "not-gay-stuff"!',
#   'Well, at the Christmas party him and Santa did some definitely    gay stuff!'],
#  81: ["OK, you've got to promise that you'll never, ever tell Ross that I told you.",
#   'About what?',
#   "He's planning your birthday party.",
#   'Oh my God! I love him!',
#   "You'd better act surprised.",
#   'About what?',
#   'My surprise party!',
#   'What surprise party?',
#   'Oh stop it. Joey already told me.',
#   "Well, he didn't tell me.",
#   "Hey, don't look at me. This is Ross's thing.",
#   "This is so typical. I'm always the last one to know everything.",
#   'No, you are not. We tell you stuff.',
#   'Yuh-huh!',
#   'I was the last one to know when Chandler got bitten by the peacock at the zoo.',
#   'I was the last one to know when you had a crush on Joey when he was moving in.',
#   'Looks like I was second to last.'],
#  82: ['Chandler, we still haven\x92t gotten an RSVP from your dad.',
#   'Oh! Right. Umm, maybe that\x92s because I didn\x92t send him an invitation.',
#   'Chandler! He\x92s your father.  he should be at the wedding.',
#   'I don\x92t even know the man. Okay? We\x92re not that close. I haven\x92t seen him in years.',
#   'Well what are you gonna do when he finds out he wasn\x92t even asked?!',
#   'It\x92s not like we run in the same circles.',
#   'I hang out with you guys, and he stars in a drag show in Vegas.',
#   'Ooh, I think I wanna trade circles.',
#   'Nobody is gonna be staring at the bride when the father of the groom is wearing a back-less dress.',
#   'So what! As long as he\x92s not wearing a white dress and a veil I don\x92t care.',
#   'Okay, I think I need to do some shopping.'],
#  83: ['Hello! Who\x92s in there?',
#   'How ya doin\x92?',
#   'Who in the hell are you?',
#   'I guess you wouldn\x92t believe me if I said I was Kurt Douglas, huh?'],
#  84: ['No-no, Rachel, don\x92t get it! He can\x92t see us!',
#   'No, yeah! The groom cannot see the bride!',
#   'I\x92m not gonna marry Chandler!',
#   'Not after this!',
#   'Okay, you guys, just relax.  I doooo.',
#   'I gotta go.',
#   'Oh, wait, Joshua! Joshua!   Yeah, well, that oughta do it.'],
#  85: ["Sorry I'm late, but I left late.",
#   'Okay.',
#   'So Pheebs, what is the book about?',
#   'I thought you said you read it in high school.',
#   'Well yeah, but then I remembered I started it and there was this pep rally and I was, I was on top of the pyramid but anyway\x97umm, what is this book about?'],
#  86: ['Excuse me, can I, can I bum one of those?',
#   "Y'know what, actually\x85  Okay, okay, okay, what's so funny over here?",
#   "I thought you didn't smoke.",
#   "Oh, I thought you guys meant marijuana cigarettes, y'know?",
#   "Y'know what I mean, like dubbies?",
#   'And I actually, I thought to myself, "Wow, those guys are crazy!"',
#   'But no, I actually smoke the regular ones all, all the time.',
#   'We get high.',
#   'Oh, me too.',
#   "I'm kidding.",
#   'Oh, me too.'],
#  87: ["Oh, are you sure you're ok?",
#   'Yeah.',
#   'Does it still hurt?',
#   'Yeah.',
#   "What a neat idea. All your clothes match. I'm gonna do this.",
#   'Hi.',
#   "Hey, how'd it go?",
#   'Excellent.',
#   'We ripped that couple apart, and kept the pieces for ourselves.',
#   "What a beautiful story. Hey, I'm fine by the way."],
#  88: ['You know what? You are right. I',
#   'Good for you Pheebs!',
#   'Ok.',
#   "Okay  If you guys have microphones in there too, I didn't mean"],
#  89: ['This sucks! I didn\x92t know I had to stay up all night before I went to this stupid sleep clinic! I\x92m so tired!',
#   'It\x92s 6:00.',
#   'Hi!',
#   'Yeah, Rach, I think you\x92re handling that really well.',
#   'Handling it?',
#   'What do you mean, handling it?',
#   'There\x92s nothing to handle.',
#   'Now, maybe I would have a problem with this if it wasn\x92t for me and Joshua.',
#   'Y\x92know, they\x92re not gonna get married anyway!',
#   'What?',
#   'Come on!',
#   'They rushed into this thing so fast it\x92s ridiculous!',
#   'And somewhere along the way, one of them is gonna realise what they\x92ve done and they\x92re call the whole thing off.',
#   'I\x92m telling ya, you\x92re gonna be dancing at my wedding before you\x92re dancing at there\x92s.'],
#  90: ['What the hell is this?!'],
#  91: ['What, did you actually thought it would make me feel better to give me stuff that I can\x92t use for another two months?!'],
#  92: ['This sucks!', 'All right, what\x92s my next present?'],
#  93: ['All right, there\x92s a nuclear holocaust, I\x92m the last man on Earth. Would you go out with me?',
#   'Enhh',
#   'I\x92ve got canned goods.',
#   'Hey, you guys! Take a look at this!  Check this baby out, dug me a hole!',
#   'Excellent hole, Joe.',
#   'Oh no! No!! My hole!!',
#   'Ow!! Ow!!!',
#   'What?! What?!! What is it?!'],
#  94: ['My drinking?',
#   'Oh, I must\x92ve said that after you left.',
#   'Said what? Exactly.',
#   'That you enjoyed the occasional drink\x85ing binge.',
#   'Oh my God!! Ohh, that is it! I\x92m leaving! You are just a horrible person!',
#   'Wait-wait-wait-wait-wait-wait-wait-wait!!',
#   'If you\x92re gonna get all sensitive about it!',
#   'I don\x92t want to lose you.',
#   'What if I, create a position for you?',
#   'I\x92ll make you an assistant buyer in this department.',
#   'Say more things like that.',
#   'You can have your own office, and a raise! Effective tomorrow.',
#   'I\x92d need an expense account.',
#   'Done!',
#   'And an assistant.',
#   'Sophie, get in here!'],
#  95: ['Monica? You gonna be very proud of me. I just got us dates with two unbelievably cute nurses.',
#   'Oh my!',
#   "They're male nurses.",
#   'Not in my head.',
#   'Anyway, they want to take us out Saturday night! What do you say?',
#   "Umm.  Umm. Umm. I don't think so.",
#   'What?',
#   'What are you talking about?!',
#   "You-you're the one who's been telling me to get over Ross and move on.",
#   "I'm moving on, and you're moving on with me.",
#   "Come on, give me one good reason why you don't wanna go.",
#   "Umm, why don't you give",
#   'What?',
#   "Harder than it sounds. Isn't it?",
#   "Okay, you're coming with me, and I also told them that if we're still here when they get off that we'll go down to the cafeteria and have some",
#   "Yep! There's always room for",
#   'Joey, how do you make',
#   "Oh, it's easy. Yeah, I-I can do it with anything. Watch uh,  Grandma's chicken salad"],
#  96: ['Hello, this is Monica...',
#   'Yeah???',
#   'Oh...',
#   "Okay, yes, we'll be right, we'll be right down.",
#   'Thank you.'],
#  97: ['Okay. Let\x92s bring it in.',
#   'Wait no, honey, honey throw it to me, throw it to me.',
#   'Here you go.',
#   'That almost hit me in the face.'],
#  98: ['Well, if the magician can open my beer with his but cheeks, then all right.'],
#  99: ['Hey!',
#   'Hey!',
#   'Y\x92know I\x92m-I\x92m really glad we decided not to sleep together before the wedding.',
#   'Oh boy, me too!',
#   'Y\x92know I was thinking if we had a\x85a big fight and uh we broke up for a few hours',
#   'Yeah?',
#   'Technically we could have sex again. What do you think, bossy and domineering?!',
#   'The wedding is off, sloppy and immature!',
#   'That\x92s me! Come on!',
#   'Okay.  But wait, we can\x92t. My Cousin Cassie is in the guest room, we\x92re supposed to have lunch.',
#   'Well, get rid of her, obsessive and shrill.',
#   'Shrill?! The wedding is back on!',
#   'I thought I heard voices. You must be Chandler.',
#   'Hi! Nice to meet you!',
#   'Nice to meet you too.',
#   'So, are you ready to go?',
#   'Yeah.',
#   'Chandler!',
#   'I\x92ll be right with you.'],
#  100: ["Th-th-that's all it is, a third nipple.",
#   'Just your run-of-the-mill third nipple.',
#   'You can take it off.',
#   'Just slice that baby right off!',
#   "Take your shirt off, and let's see what we're dealing with here.  What are you doing?",
#   'Just showing you my run-of-the-mill-slice-it-right-off third nipple.',
#   "Well that's not a third nipple.",
#   'No?'],
#  101: ["First of all, it's on your ass.", 'Well then, what is it?!'],
#  102: ['Wait a minute, hold it.  Johnson! Will you come in here a moment?',
#   "I'm with Hamilton!",
#   "He's good with rear things, bring him in too."],
#  103: ['Umm, this is great wine.',
#   'It\x92s from France\x85In Europe\x85Western Europe. Y\x92know umm, a few years ago I actually was backpacking across Western Europe.',
#   'Really?',
#   'Uh-hmm\x97Wait! It gets better. Um, yeah I was in Barcelona.',
#   'I studied for a year in Barcelona.',
#   'Anyway, umm so I was um, I was hiking',
#   'I love hiking!',
#   'Oh that\x92s great! I was hiking along the foothills of Mount Tibidaybo'],
#  104: ['So? Congratulations you two, I didn\x92t even know you got married.',
#   'Oh we-we didn\x92t.'],
#  105: ['No-no. We', 'What?!'],
#  106: ['Um uh\x85We\x92re-we\x92re just having this baby together but uh, uh that\x92s all.',
#   'Why?!!',
#   'Uh well umm\x85we\x92re just not in that place, y\x92know? But we\x92re very excited about this.',
#   'Oh. Well then shut me up.',
#   'Just tell me how.',
#   'Uh-oh, I feel another one coming.'],
#  107: ['Let it go, Ross.',
#   "Yeah, well, you didn't know Chi Chi.",
#   'Do you all promise?',
#   'Chandler? Do you promise to be good?',
#   'You can come in, but your filter-tipped little buddy has to stay outside!',
#   'Hey, Pheebs.',
#   'Dear Ms. Buffay.',
#   'Thank you for calling attention to our error.',
#   'We have credited your account with five hundred dollars.',
#   "We're sorry for the inconvenience, and hope you'll accept this-  -"],
#  108: ['Oh my God, honey we are so meant to be together. We both have copies of the',
#   'Honey, both yours.',
#   'Hey! Great advice on that Joey thing!',
#   'Yeah? The work problem?',
#   'Oh it was perfect! I mean it really felt like he was my friend again.',
#   'What problem did you tell him you had?',
#   'Oh that\x92s not important. The point is, I really\x97I think everything\x92s gonna be okay.'],
#  109: ['Okay, I\x92ve got some Ones, you wanna put them in her panties?',
#   'No thanks, Mom!',
#   'Ha-ha, it\x92s not my baby, ha-ha-ha!',
#   'Very good,  so good.',
#   'I really, really enjoyed it. Very exotic.',
#   'Well, I just checked our messages and Joshua didn\x92t call.',
#   'I mean you\x92d think he\x92d be worried about me not showing up at his club.',
#   'Ugh, you know what makes it so much worse, Ross is all happy in Vermont!',
#   'Come on! Look where you are!!',
#   'When you get a sec, another round of daiquiris.',
#   'Remember, a virgin for me please.',
#   'Oh! And don\x92t let me leave without getting the name of that carpet guy.',
#   'Ahh, come on! Y\x92know what\x97y\x92know what, I think I\x92m just gonna go home and call Kathy.',
#   'Well, if you think it will help.',
#   'No!',
#   'That was a test!',
#   'In a couple of hours I\x92m gonna get really drunk and wanna call Kathy and you guys are gonna have to stop me!',
#   'And then after that, I\x92m gonna get so drunk, I\x92m gonna wanna call Janice',
#   'You should! How is she?',
#   'Ohhh!!',
#   'I think somebody needs another lap dance.'],
#  110: ['All right, I definitely taste nutmeg.',
#   'You do?',
#   'You don\x92t?  Well, that\x92s the difference between a professional and a layman.',
#   'That and arrogance.',
#   'Hey.',
#   'Hey! How was sailing?'],
#  111: ['Wow thanks!',
#   'Joe?',
#   'Yeah!',
#   'Uh, you\x92ve had a lot of sex right?',
#   'When? Today? Some, not a lot.',
#   'Well, it\x92s just the reason that I\x92m asking is because I kind of eh, uh, I was unable to\x97I mean I really wanted to, but I couldn\x92t\x85.',
#   'There huh\x97hmm, there-there was an incident.',
#   'Don\x92t worry about that man, that happens.',
# ...
#   'I made a promise that--Oh hey!',
#   'What?',
#   "You're nose is bleeding!",
#   'Oh God.',
#   'No!',
#   'Oh not again!',
#   'This-this happened when my grandfather died.',
#   "It's ugh!",
#   'Sorry.',
#   "Oh, okay, so I'm sorry, what-what were you-what did you want to tell me?",
#   'Umm',
#   'Sorry. Sorry.',
#   "Okay, I uh, I can't see you anymore.",
#   "Yeah, I know. It's ridiculous! I can't see you either."],
#  965: ['Not yet! Not yet! Not yet! Not yet! Not yet! Not yet! Not yet! Not yet!',
#   'Hello, Chip.',
#   'Hey, Rach! How ya doin\x92?',
#   'I\x92m great! I\x92m great. I\x92ve got a great job at',
#   'So ah, Monica ready yet?',
#   'She\x92ll be out in a second. So, Chip, how\x92s umm, Amy Welch?',
#   'Amy Welch? Wow! I haven\x92t seen her since... So, Monica about ready?'],
#  966: ['That\x92s right, I love you! And-and I\x92m gonna play with you all the time.',
#   'How can you let him talk to your crotch like that?',
#   'He\x92s talking to the baby.',
#   'Ohh!',
#   'Okay!',
#   'Okay, cause when-when he said, "I can\x92t wait to hear your first words," I thought, "There\x92s a trick."',
#   'Okay. Well, I gotta go you guys. I\x92ll see you later.',
#   'Okay.'],
#  967: ['Oh my, oh my God!',
#   'Aw, it\x92s unbelievable!',
#   'Wow!',
#   'She is kicking so much!',
#   'Oh, she\x92s like umm\x85oh\x85who\x92s that kind of annoying girl soccer player?',
#   'Mia Hamm?',
#   'Mia Hamm!',
#   'Oh that\x92s amazing.',
#   'Oh-oh!! One hand on the sheet Joe!',
#   'Whoa-hey-oh! Sorry!'],
#  968: ['Okay, what do you guys think?',
#   'Dude!',
#   'I have never known love like this.',
#   'You really like it?',
#   'Dude! How-how did you write this?',
#   'I stole Monica\x92s and changed the name.',
#   'You can\x92t',
#   'If he goes first he can!'],
#  969: ['Yeah!',
#   'Anyway, I-I still think we should try to patch things up, y\x92know?',
#   'Like uh, maybe we could get him to get tickets to another Knicks game and invite him.',
#   'Oh wow that\x92s a great idea! And',
#   'Here you go.',
#   'Hey-hey-hey-ho-ho, I got this one.',
#   'Here you go.'],
#  970: ['Y\x92know I gotta tell ya, sometimes I just\x97I don\x92t get Chandler.'],
#  971: ['Y\x92know, me and him do stuff all the time without you and you don\x92t get all upset.',
#   'All the time?',
#   'All the time!'],
#  972: ['Cassie, how you-how you doin\x92 on that\x85hot dog.',
#   'I\x92m all done.',
#   'Thank God.',
#   'I guess the last time we really hung out was when our parents rented that beach house together.',
#   'Oh right.',
#   'Right.',
#   'Ooh, remember the time I uh, I pinned you down and tickled you \x91til you cried?',
#   'We\x92re probably too old to do that now.',
#   'I\x92ll always remember that summer, because it\x92s when I got all of these freckles.',
#   'Uh-huh! Uh-huh! And-and-and I\x92ll always remember that summer because that\x92s when I realized that we are related.',
#   'It took you that long to figure it out, huh?',
#   'Well I\x92m, I\x92m a little slow.  Just as our children would be.'],
#  973: ['Relax every muscle in your body.',
#   'Listen to the plinky-plunky music.',
#   'Okay, now close you eyes, and think of a happy place.',
#   'Okay, tell me your happy place.',
#   "Richard's living room, drinking wine.",
#   'All right. No, no, no, not a Richard thing, just put down the glass. And get out!',
#   "I'm sorry, but that's my happy place.",
#   'Well, okay, fine, use my happy place.',
#   "Okay, I'm just gonna, I have to ask that you don't move anything.",
#   "All right, I'll try not to.",
#   'Okay, all right, so, your in a meadow, millions of stars in the sky....',
#   'Do you think breaking up with him was a huge mistake?',
#   'All right, there are no questions in the happy place. Okay, just, the warm breeze, and the moonlight flowing through the trees....',
#   "I'll bet he's totally over me, I'll bet he's fine.",
#   "All right, betting and wagering of any kind, are, I'm sure, not permitted in the happy place.",
#   'Okay.',
#   'Just-just, you know, the-the lovely waterfalls, and the, the trickling fountains.',
#   'And the-the calming sounds of the babbling brook....',
#   "Okay, this isn't working. I'm still awake and now I have to pee."],
#  974: ["OK sweetie, I'll see you later.", 'See you later Rach.'],
#  975: ['Bye-bye Julie.',
#   'Hey.',
#   'Hey.',
#   "Hey, c'mon, cut it out.",
#   'Hey?',
#   'What?',
#   "Can I ask you somethin'?"],
#  976: ["Hey Rach, wanna hear the new song I'm thinkin' of singing this afternoon? I wrote it this morning in the shower.",
#   'Ok.',
#   'Uh, Rachel, sweetheart, could I see ya for a minute?',
#   "What's up?",
#   'F.Y.I..',
#   "I've decided to pay a professional musician to play in here on Sunday afternoons.",
#   'Her name is Stephanie... something.',
#   "She's supposed to be very good.",
#   'But what about Phoebe?',
#   "Rachel, it's not that your friend is bad, it's that she's so bad, she makes me want to put my finger through my eye into my brain and swirl it around.",
#   "Ok, ok, so you're not a fan, but I mean, come on, you cannot do this to her.",
#   'Uh...',
#   'Oh, no no no no. Oh no no no no. I have to do this to her?'],
#  977: ['Ahh, no.',
#   'Oh.',
#   'Are you jealous?',
#   "Noo, I y'know I don't see why she has to play with you, that's all.",
#   "I mean doesn't she have any y'know other stripper moms friends of her own?",
#   'You are totally jealous.',
#   "I'm not jealous.",
#   "All right this is about, umm, people feeling certain things y'know about strippers.",
#   "And y'know, and um, I...",
#   'Honey, I love you too.',
#   'Ugh. Wait, wait, wait.',
#   'What?',
#   'Huh.',
#   "Well, there's a kiss that he won't forget for a couple of hours, y'know.",
#   'Yeah. Either that, or you just turned him on and sent him off to a stripper.'],
#  978: ['I can\x92t believe you came back.',
#   'Don\x92t say anything.',
#   'I don\x92t wanna speak, I don\x92t wanna think.',
#   'I just want you to take me and kiss me and make love to me right here, right now.',
#   'Rachel! Rachel!',
#   'What?',
#   'You missed the exit!',
#   'Oh, sorry.',
#   'My God, what were you thinking about?',
#   'Um,  Barry.',
#   'Awwwww'],
#  979: ["I just\x97I thought you guys were doing it, I didn't know you were in love!",
#   'Dude!',
#   'And hats off to Phoebe. Quite a competitor.  And might I say your breasts are still showing.',
#   'God!',
#   "All right! So that's it! It's over! Everybody knows!",
#   "Well actually, Ross doesn't.",
#   "Yes, and we'd appreciate it if no one told him yet."],
#  980: ['Dear Mary-Angela.',
#   'Hi.',
#   'How?s it going.',
#   'This is the hardest letter I?ve ever had to write.',
#   'What the hell?s a matter with you?',
#   'How do you think Joey?s going to react when he finds out that you blew off his sister with a letter?',
#   'Well, that?s the part where you tell him that I moved to France. When actually I?ll be in Cuba.',
#   'All right, look, look, you?ve got to do this yourself, okay in person.',
#   'At least you know her name.',
#   'You just go to the house and you ask for Mary-Angela, okay, when which ever one she is comes to the door, you take her for a walk, you let her down easy.',
#   'What if Mary-Angela comes to the door and I ask for Mary-Angela?',
#   'Where in Cuba?'],
#  981: ['Hey.',
#   'You uh, you may have been right about Jill.',
#   'Oh! I knew it! What happened?',
#   'Umm, she kissed me.',
#   'What?! You kissed!'],
#  982: ['All right.',
#   'Okay, here you go.  I have two queens, what do you have?',
#   'A two and a five.',
#   'Ho-ho, you win! 50 dollars!',
#   'Really?!',
#   'Oh yeah! Okay, let\x92s play again.  What do you got?',
#   'A four and a nine.',
#   'You\x92re kidding right?',
#   'No. Why?',
#   'Well that\x92s a full cup!',
#   'Damn! I am good at Cups!'],
#  983: ['What? Why? Where are you?',
#   'I\x92m still on the set!',
#   'Joey! The wedding is in less than an hour!',
#   'I know! I\x92m sorry! The guy\x92s drunk, they won\x92t let me go until we get this.',
#   'Oh my God! I\x92m gonna have to find another minister.',
#   'No! No, I\x92m the minister! Alright, look-look, put \x91em both on the phone, I\x92ll marry them right now.',
#   'Ugh! Joey, I have to go.',
#   'Hey! Don\x92t you hang up on me! I\x92ll marry you and me right now! I have the power!'],
#  984: ["Oh hey Joey! What's up?",
#   "I can't decide which route to take to Vegas. Hey, you've traveled a lot right?",
#   "Yeah, I've been around.",
#   'Okay, so-so which route should I take the northern route or the southern route?',
#   "Ooh, if you take the northern route there's a man in Illinois with a beard of bees.",
#   'Great! Problem solved!'],
#  985: ['Estelle, you gotta get me some work. I-I lost my health insurance.',
#   'All right, first thing we gotta do, damage control.',
#   'Why?',
#   'Well, I think uhh, someone out there may have been bad mouthing you all over town.',
#   'Bastard!'],
#  986: ["You mean whenever Monica and Chandler where like y'know doing laundry or going grocery shopping or\x97Oh!",
#   'All that time Monica spent on the phone with sad Linda from camp!',
#   'Uh-huh, doing it. Doing it. Phone doing it.',
#   "Oh, I can't believe it!",
#   "I mean I think it's great!",
#   'For him.',
#   'She might be able to do better.',
#   'Hey guys!',
#   'Joey! Come here! Come here!',
#   'Phoebe just found out about Monica and Chandler.',
#   "You mean how they're friends and nothing more?",
#   'No. Joey, she',
#   "Okay, so now they know that you know and they don't know that Rachel knows?",
#   "Yes, but y'know what?",
#   "It doesn't matter who knows what.",
#   'Now, enough of us know that we can just tell them that we know!',
#   'Then all the lying and the secrets would finally be over!'],
#  987: ["It's a tradition, like the parade. If the parade decided it was gay, moved out, and abandoned its entire family."],
#  988: ['Y\x92know, you\x92re friend\x92s getting married, it\x92s gotta change things.',
#   'You really think it would be that different?',
#   'How could it not be?',
#   'I mean pretty soon they\x92re gonna be having kids, and then they\x92re just gonna be hanging out with other couples who have kids.',
#   'And then maybe they\x92re gonna have to leave the city to be near a',
#   'Well, things change.',
#   'I don\x92t want them to move to a',
#   'It\x92ll be okay Joe.'],
#  989: ['Its still there!',
#   'Mrs. Braverman must be out.',
#   'She could be out of town. Maybe she\x92ll be gone for months.',
#   'By then, the cheesecake may have gone bad. We don\x92t want her to come back to bad cheesecake.',
#   'No that could kill her.',
#   'Well, we don\x92t want that.',
#   'No, so we\x92re protecting her.',
#   'But we should take it.',
#   'But we should move quick.',
#   'Why?',
#   'Because I think I just heard her moving around in there.',
#   'Go! Go! Go! Go! Go! Go! Go! Go! Go! Go!'],
#  990: ["Hey, Kicky. What're you doing?",
#   "Just trying to get comfortable. I can't sleep in my underwear.",
#   "Well, you're gonna.",
#   "I've been thinking. Y'know, about how I'm always seeing girls on top of girls...",
#   'Are they end to end, or tall like pancakes?',
#   "Y'know what I mean, about how I'm always going out with all these women.",
#   "And I always figured, when the right one comes along, I'd be able to be a stand-up guy and go the distance, y'know?",
#   "Now I'm looking at my dad, thinking...",
#   "Hey, you're not him.",
#   "You're you.",
#   "When they were all over you to go into your father's pipe-fitting business, did you cave?",
#   'No.',
#   'No.',
#   'You decided to go into the out-of-work actor business.',
#   "Now that wasn't easy, but you did it!",
#   'And I\'d like to believe that when the right woman comes along, you will have the courage and the guts to say "No thanks, I\'m married."',
#   'You really think so?',
#   'Yeah. I really do.',
#   'Thanks, Chandler.',
#   'Get off!'],
#  991: ['Hi.',
#   'Your Fettuccini Alfredo looks a little dry, did you use all your cheese?',
#   'When you say used, do you mean eat as a pre-cooking snack?',
#   'And the cream?',
#   'Cheese makes me thirsty.',
#   'Okay. Let\x92s move on.',
#   'All right.',
#   'Oh! Something smells good over at Monica\x92s station!  Oh my God! This is absolutely amazing! You\x92ve never made this before?',
#   'Oh no!',
#   'I don\x92t know anything about cooking.',
#   'I had to ask someone what it\x92s called when the, when the water makes those little bubbles.',
#   'Well, hats off to the chef.',
#   'I-I-I\x92m sorry, your-your mouth was full, I didn\x92t hear what you said. Umm, hats off to who now?',
#   'The chef!',
#   'That\x92s right.'],
#  992: ['Hey, Pheebs.',
#   'Hey.',
#   "How's it going?",
#   "Good. Oh oh! Roger's having a dinner thing and he wanted me to invite you guys.",
#   "So what's going on?",
#   "Nothing, um, it's just, um... It's Roger.",
#   "I dunno, there's just something about...",
#   "Basically we just feel that he's...",
#   'We hate that guy.',
#   'Yeah. Hate him.',
#   "We're sorry, Pheebs, we're sorry.",
#   'Uh-huh.',
#   'Okay.',
#   "Okay, don't you think, maybe, though, it's just that he's so perceptive that it freaks you out?",
#   '...No, we hate him.',
#   "We're sorry."],
#  993: ['Hey!',
#   'Hey!',
#   'What are you doing?',
#   'I\x92m sending back all this stuff that Chandler bought out of guilt.'],
#  994: ['Yes that was mine.',
#   "Cause I figured you'd hooked up with some girl and she'd left it there.",
#   'Yes that would have made more sense.',
#   "Y'know, I-I don't even feel like I know you anymore man!",
#   "All right, look, I'm just gonna ask you this one time.",
#   "And whatever you say, I'll believe ya.",
#   'Were you, or were you not on a gay cruise?'],
#  995: ["Oh hey! There's some kids playing in the street, you wanna go down there and give them a project, ruin their day?",
#   'Hey, if they have a ball maybe you can stick razor blades in it and teach them a new game, Gonna Need Stitches Ball.'],
#  996: ['She said what?',
#   'She said, "If I\x92m not gonna be happy getting married somewhere that we find in a day, well then we should just postpone it."',
#   'Postpone it?',
#   'Emily, do you think Monica realises how much our parents spent on this wedding?',
#   'Do you my sister\x92s teeny-tiny little brain comprehends that people took time out of their lives to fly thousands of miles to be here, huh?',
#   'This isn\x92t right.',
#   'I realize that people are going to be disappointed. But, I\x92m sure they\x92ll come back when we can do it right.',
#   'I can\x92t ask people to do that? Would you ask people to do that?',
#   'Don\x92t you point your pants at me!',
#   'We have no choice!',
#   'Anywhere that\x92s half-decent would\x92ve be booked months ago, Ross don\x92t you understand?',
#   'This is our wedding I\x92m talking about.',
#   'The only thing I understand is postponing it is not an option. This is when we\x92re getting married.',
#   'So what are you saying? It\x92s now or never?',
#   'No. I\x92m saying it\x92s now.',
#   'Or?',
#   'There\x92s no \x91or\x92 in mind. What is wrong with these pants?!!',
#   'It\x92s not the pants.',
#   'It\x92s you that is backwards.',
#   'And if, and if you don\x92t understand how important this is to me, well then, perhaps we shouldn\x92t get married at all!',
#   'No, wait! Emily! No, wait, stop! Emily, please\x97'],
#  997: ['Hi, honey.',
#   'See you later.',
#   'What? I-I bought groceries, I was gonna make you dinner!',
#   'Well next time ask! Or at least wait for me to ask!',
#   'Hi, this is Heldi from the Morgan Chase museum. I\x92m calling for Monica Geller.',
#   'Oh no!',
#   'I want to let her know that there was a cancellation and if she\x92s still interested in having the Bing-Geller wedding at our facility, it is available',
#   'Oh please, he didn\x92t hear it! He didn\x92t hear it!!',
#   'This is Chandler Bing! This is Chandler Bing!',
#   'NOOOO!!!!!!!!'],
#  998: ["Ma! What're you doing here?",
#   'I came to give you this  and this.',
#   'Oww! Big ring!'],
#  999: ['Yeah, all the time. I want the baby to know my voice.',
#   'Do you uh, do you talk about me?',
#   'Yeah, yeah, all the time.',
#   'Really?',
#   'But um, we just refer to you as Bobo the Sperm Guy.'],
#  1000: ['Would you look at this dump? He hated us. This is his final revenge!',
#   'Have you ever seen so much crap?',
#   'Actually, I think this apartment sullies the good name of crap',
#   'Check this out. Can I have this?'],
#  ...}

# %%
train_df = pd.read_csv('meld/train_sent_emo.csv')

# %%
train_df.Speaker.unique()
# Out:
# array(['Chandler', 'The Interviewer', 'Joey', 'Rachel', 'Monica',
#        'Phoebe', 'Ross', 'Sergei', 'Customer', 'Jade', 'Mona', 'Charlie',
#        'Paleontologist', 'Professore Clerk', 'Caitlin', 'Nurse',
#        'Mr. Treeger', 'Carol', 'The Casting Director', 'Emily',
#        'Elizabeth', 'Paul', 'The Dry Cleaner', 'Joey and Chandler',
#        'Kate', 'The Director', 'Mr. Tribbiani', 'Guru Saj', 'Wayne',
#        'Richard', 'Dina', 'Bobby', 'Danny', 'Krista', 'Jill', 'Doug',
#        'Stevens', 'Bob', 'Mr. Franklin', 'Director', 'Janice', 'Tony',
#        'Peter', 'Ticket Counter Attendant', 'Dr. Long', 'Charlton Heston',
#        'Joshua', 'Nancy', 'Kim', 'Joanna', 'Cassie', 'Dr. Rhodes',
#        'Dr. Johnson', 'Kristen', 'Jester', 'Sarah', 'Pete',
#        'The Singing Man', 'Commercial', 'Mark', 'A Female Student', 'All',
#        'Cliff', 'Tag', 'Eric', 'Dr. Green', 'Mr. Heckles', 'Mr. Geller',
#        'Sophie', 'Singer', 'David', 'Hitchhiker', '1st Customer',
#        '2nd Customer', '3rd Customer', 'The Presenter', 'Policeman',
#        'Duncan', 'Jane', 'Message', 'Gary', 'Bonnie', 'Woman', 'Leslie',
#        'Isabella', "Joey's Hand Twin", 'Kiki', 'Joanne', 'Fireman No. 3',
#        'Susan', 'Mischa', 'The Assistant Director', 'Mrs. Geller',
#        'Emeril', 'Man', 'Jake', 'Tom', 'Lecturer', 'The Woman',
#        'Monica and Ross', 'The Vendor', 'Julio', 'Janine', 'Julie',
#        'Dr. Baldhara', 'Young Ethan', 'Dr. Leedbetter', 'Phoebe Sr.',
#        'Katie', 'Gunther', 'Earl', 'Barry', 'Robbie', 'Lydia', 'Bernice',
#        'Mindy', 'Robert', 'Issac', 'Chloe', 'Supervisor', 'Kathy',
#        'Voice', 'Stu', 'Tour Guide', 'Dr. Ledbetter', 'Mrs. Burgin',
#        'Mr. Burgin', 'Annabelle', 'Flight Attendant', 'Roger',
#        'Front Desk Clerk', 'Mr. Zelner', 'Student', 'Jason', 'Guy', 'Jim',
#        'Liam', 'Phoebe Sr', 'Stage Director', 'PBS Volunteer',
#        'Gary Collins', 'Carl', 'Phoebe and Rachel', 'The Cigarette Guy',
#        'Lorraine', 'an', 'Richard’s Date', 'Frank', 'Rachel and Phoebe',
#        "Mona's Date", 'Ross and Joey', 'Mike', 'Dr. Miller', 'Both',
#        'Receptionist', 'Mrs. Green', 'Marc', 'Dana', 'The Fireman',
#        'Drunken Gambler', 'Raymond', 'Kristin', 'Monica and Phoebe',
#        'A Student', 'Hoshi', 'Ben', 'Teacher', 'Stephanie', 'Evil Bitch',
#        'Sick Bastard', 'Kyle', 'Nurse #1', 'Nurse #2',
#        'Dr. Stryker Ramoray', 'Helena', 'Angela', 'Steve',
#        'Airline Employee', 'Janitor', 'Mr. Posner', 'Mrs. Lynch', 'Paolo',
#        'Megan', 'Joey and Ross', 'Hombre Man', 'Dr. Zane', 'Alice',
#        'Russell', 'Chip', 'The Lurker', 'The Security Guard',
#        'The Librarian', 'The Head Librarian', 'Guy #1', 'Shelley', 'Girl',
#        'Leader', 'Dr. Wesley', 'Dr. Drake Remoray', 'Hope', 'Stranger',
#        'Hold Voice', 'Rick', 'Vince', 'Phoebe/Waitress', 'Joey/Drake',
#        'Rachel/actress', 'Mr. Waltham', 'Mrs. Waltham', 'Ms. McKenna',
#        'Fake Monica', 'Doctor', 'Boy in the Cape', 'Mrs. Chatracus',
#        'Paula', 'Burt', 'Ursula', 'Older Scientist', 'Another Tour Guide',
#        'Another Scientist', 'The Potential Roommate', 'Aunt Lillian',
#        'Ronni', 'Cecilia', 'Hotel Clerk', 'Casey', 'The Instructor',
#        'Jay Leno', 'The Smoking Woman', 'Trudie Styler',
#        'The Acting Teacher', 'Dr. Franzblau', 'Mrs. Tedlock', 'The Guys',
#        'The Museum Official', 'The Croupier', 'Jeannine', 'The Conductor',
#        'Woman On Train', 'The Food Critic', 'The Cooking Teacher',
#        'Waiter', 'Allesandro', 'Terry', 'Friend No. 2', 'Friend No. 1',
#        'Her-Friends', 'Estelle', 'Mrs. Tribbiani', 'Larry',
#        'Fireman No. 1', 'Fireman No. 2', 'Dr. Oberman', 'Gerston',
#        'Santos', 'Petrie', "Maitre d'", 'Melissa', 'Stanley', 'The Grip'],
#       dtype=object)

# %%
train_df.Speaker = train_df.Speaker.replace(['Monica'], 'Monica Geller')
train_df.Speaker = train_df.Speaker.replace(['Ross'], 'Ross Geller')
train_df.Speaker = train_df.Speaker.replace(['Chandler'], 'Chandler Bing')
train_df.Speaker = train_df.Speaker.replace(['Phoebe'], 'Phoebe Buffay')
train_df.Speaker = train_df.Speaker.replace(['Joey'], 'Joey Tribbiani')
train_df.Speaker = train_df.Speaker.replace(['Rachel'], 'Rachel Green')
train_df.Speaker = train_df.Speaker.replace(['David'], 'David “The Scientist Guy“')
train_df.Speaker = train_df.Speaker.replace(['Carol'], 'Carol Willick')
train_df.Speaker = train_df.Speaker.replace(['Emily'], 'Emily Waltham')
train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Richard')] = train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Richard')].replace(['Richard'], 'Richard Crosby')
train_df.Speaker = train_df.Speaker.replace(['Richard'], 'Richard Burke')
train_df.Speaker = train_df.Speaker.replace(['Mr. Geller'], 'Jack Geller')
train_df.Speaker = train_df.Speaker.replace(['Mrs. Geller'], 'Judy Geller')
train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Jill')] = train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Jill')].replace(['Jill'], 'Jill Green')
train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Jill')] = train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Jill')].replace(['Jill'], 'Jill Goodacre')
train_df.Speaker = train_df.Speaker.replace(['Pete'], 'Pete Becker')
train_df.Speaker = train_df.Speaker.replace(['Mike'], 'Michael “Mike” Hannigan')
train_df.Speaker = train_df.Speaker.replace(['Janice'], 'Janice Hosenstein')
train_df.Speaker = train_df.Speaker.replace(['Charlie'], 'Charlie Wheeler')
train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Julie')] = train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Julie')].replace(['Julie'], 'Julie Graff')
train_df.loc[(train_df.Season==8) & (train_df.Speaker=='Julie')] = train_df.loc[(train_df.Season==8) & (train_df.Speaker=='Julie')].replace(['Julie'], 'Julie Coreger')
train_df.loc[4374] = train_df.loc[4374].replace(['Julie', 470, 0, 6], ['Julie Coreger', 469, 2, 8])
train_df.Speaker = train_df.Speaker.replace(['Ursula'], 'Ursula Buffay')
train_df.Speaker = train_df.Speaker.replace(['Susan'], 'Susan Bunch')
train_df.Speaker = train_df.Speaker.replace(['Dr. Green'], 'Leonard Green')
train_df.Speaker = train_df.Speaker.replace(['Dr. Drake Remoray'], 'Dr. Drake Ramoray')
train_df.Speaker = train_df.Speaker.replace(['Phoebe Sr'], 'Phoebe Abbott')
train_df.Speaker = train_df.Speaker.replace(['Phoebe Sr.'], 'Phoebe Abbott')
train_df.Speaker = train_df.Speaker.replace(['Frank'], 'Frank Buffay Jr.')
#train_df.loc[(train_df.Season==5) & (train_df.Speaker=='Gary')] = train_df.loc[(train_df.Season==5) & (train_df.Speaker=='Gary')].replace(['Gary'], 'Gary')
train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Gary')] = train_df.loc[(train_df.Season==7) & (train_df.Speaker=='Gary')].replace(['Gary'], 'Gary (neighbor)')
train_df.Speaker = train_df.Speaker.replace(['Mr. Zelner'], 'Mr. R. Zelner')
train_df.Speaker = train_df.Speaker.replace(['Jim'], 'Jim Nelson')
train_df.Speaker = train_df.Speaker.replace(['an'], 'Catherine')
train_df.Speaker = train_df.Speaker.replace(['Tag'], 'Tag Jones')
train_df.Speaker = train_df.Speaker.replace(['Ben'], 'Ben Geller')
train_df.Speaker = train_df.Speaker.replace(['Barry'], 'Barry Farber')
train_df.Speaker = train_df.Speaker.replace(['Mrs. Green'], 'Sandra Green')
train_df.Speaker = train_df.Speaker.replace(['Alice'], 'Alice Knight')
train_df.Speaker = train_df.Speaker.replace(['Mrs. Tribbiani'], 'Gloria Tribbiani')
train_df.Speaker = train_df.Speaker.replace(['Mr. Waltham'], 'Stephen Waltham')
train_df.Speaker = train_df.Speaker.replace(['Mrs. Waltham'], 'Andrea Waltham')
train_df.Speaker = train_df.Speaker.replace(['Janine'], 'Janine Lecroix')
train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Elizabeth')] = train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Elizabeth')].replace(['Elizabeth'], 'Elizabeth Stevens')
train_df.loc[(train_df.Season==5) & (train_df.Speaker=='Elizabeth')] = train_df.loc[(train_df.Season==5) & (train_df.Speaker=='Elizabeth')].replace(['Elizabeth'], 'Elizabeth Hornswoggle')
train_df.Speaker = train_df.Speaker.replace(['Helena'], 'Charles Bing (Helena Handbasket)')
train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Paul')] = train_df.loc[(train_df.Season==6) & (train_df.Speaker=='Paul')].replace(['Paul'], 'Paul Stevens')
train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Paul')] = train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Paul')].replace(['Paul'], 'Paul the Wine Guy')
train_df.Speaker = train_df.Speaker.replace(['Joshua'], 'Joshua Burgin')
train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Bobby')] = train_df.loc[(train_df.Season==1) & (train_df.Speaker=='Bobby')].replace(['Bobby'], 'Bobby Rush')
train_df.loc[(train_df.Season==8) & (train_df.Speaker=='Bobby')] = train_df.loc[(train_df.Season==8) & (train_df.Speaker=='Bobby')].replace(['Bobby'], 'Bobby Corso')
train_df.Speaker = train_df.Speaker.replace(['Mindy'], 'Mindy Hunter')
train_df.Speaker = train_df.Speaker.replace(['Estelle'], 'Estelle Leonard')
train_df.Speaker = train_df.Speaker.replace(['Cecilia'], 'Cecilia Monroe')


train_df.loc[7387, 'Speaker']='the Soap Actor'
train_df.loc[3306, 'Speaker']='Male Guest'
train_df.loc[3614, 'Speaker']='Jim Nelson'

uttr_id=0
for index, row in train_df[(train_df.Dialogue_ID>=879) & (train_df.Dialogue_ID<=883)].iterrows():
    train_df.loc[index, 'Dialogue_ID']=879
    train_df.loc[index, 'Utterance_ID']=uttr_id
    uttr_id=uttr_id+1
    train_df.loc[index, 'Season']=7
    train_df.loc[index, 'Episode']=4
    
train_df.loc[3588, 'Speaker']='Mark'
uttr_id=0
for index, row in train_df[(train_df.Dialogue_ID>=379) & (train_df.Dialogue_ID<=381)].iterrows():
    train_df.loc[index, 'Dialogue_ID']=379
    train_df.loc[index, 'Utterance_ID']=uttr_id
    uttr_id=uttr_id+1
    train_df.loc[index, 'Season']=3
    train_df.loc[index, 'Episode']=19
    
train_df.loc[5500, 'Speaker']='Ross Geller'
uttr_id=0
for index, row in train_df[(train_df.Dialogue_ID>=586) & (train_df.Dialogue_ID<=587)].iterrows():
    train_df.loc[index, 'Dialogue_ID']=586
    train_df.loc[index, 'Utterance_ID']=uttr_id
    uttr_id=uttr_id+1
    train_df.loc[index, 'Season']=3
    train_df.loc[index, 'Episode']=11
    
uttr_id=0
for index, row in train_df[(train_df.Dialogue_ID>=543) & (train_df.Dialogue_ID<=544)].iterrows():
    train_df.loc[index, 'Dialogue_ID']=543
    train_df.loc[index, 'Utterance_ID']=uttr_id
    uttr_id=uttr_id+1
    train_df.loc[index, 'Season']=4
    train_df.loc[index, 'Episode']=16

# %%
train_df[(train_df.Speaker=='Cecilia')]
# Out:
#       Sr No.                                          Utterance  Speaker  \
# 8252    8689  Y’know what? It doesn’t matter! Because it is ...  Cecilia
# 8254    8691                           And if it were true, how  Cecilia
#
#       Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 8252    anger  negative          868             0       7       15
# 8254  neutral   neutral          868             2       7       15
#
#          StartTime       EndTime
# 8252  00:05:44,510  00:05:47,679
# 8254  00:05:49,223  00:05:52,893

# %%
train_df[(train_df.Dialogue_ID>=542) & (train_df.Dialogue_ID<=544)]
# Out:
#       Sr No.                                          Utterance  \
# 5107    5387  So who’s idea was it to put everybody in the d...
# 5108    5388  Oh, some idiot customer put a suggestion in th...
# 5109    5389                      Oh my God, they took my idea!
# 5110    5390                                     That was you?!
# 5111    5391                           Yeah! Okay, here you go.
# 5112    5392                        Rachel, I made you a cocoa.
# 5113    5393                      Oh my God, are you guys okay?
# 5114    5394                                 Are you all right?
# 5115    5395                                             Oh my.
# 5116    5396                                               Sit!
# 5117    5397                                                Hi.
# 5118    5398                                Oh my gosh, Joshua!
# 5119    5399      All those things I said about not being ready
# 5120    5400                                  They’re not true?
# 5121    5401                      No, they’re-they’re all true.
# 5122    5402                                                Oh.
# 5123    5403                                                But
# 5124    5404                           Oh! Oh, I love that but.
# 5125    5405          You wanna go inside and have some coffee?
# 5126    5406                                              Yeah.
# 5127    5407                                 Okay.  Every time.
#
#              Speaker   Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  \
# 5107    Rachel Green   neutral   neutral          542             0       3
# 5108   Monica Geller     anger  negative          542             1       3
# 5109   Phoebe Buffay  surprise  positive          542             2       3
# 5110   Monica Geller  surprise  negative          542             3       3
# 5111   Phoebe Buffay       joy  positive          542             4       3
# 5112         Gunther   neutral   neutral          542             5       3
# 5113   Phoebe Buffay  surprise  negative          542             6       3
# 5114         Gunther  surprise  negative          542             7       3
# 5115  Joey Tribbiani  surprise  positive          542             8       3
# 5116    Rachel Green     anger  negative          543             0       2
# 5117          Joshua   neutral   neutral          543             1       2
# 5118    Rachel Green  surprise  positive          543             2       2
# 5119   Joshua Burgin   neutral   neutral          544             0       4
# 5120    Rachel Green      fear  negative          544             1       4
# 5121   Joshua Burgin   neutral   neutral          544             2       4
# 5122    Rachel Green       joy  positive          544             3       4
# 5123   Joshua Burgin   neutral   neutral          544             4       4
# 5124    Rachel Green  surprise  positive          544             5       4
# 5125    Rachel Green   neutral   neutral          544             6       4
# 5126   Joshua Burgin   neutral   neutral          544             7       4
# 5127    Rachel Green   neutral   neutral          544             8       4
#
#       Episode     StartTime       EndTime
# 5107       21  00:00:02,711  00:00:05,713
# 5108       21  00:00:05,880  00:00:08,924
# 5109       21   0:00:09,217   0:00:10,889
# 5110       21   0:00:10,889   0:00:11,351
# 5111       21  00:00:11,469  00:00:14,680
# 5112       21  00:00:15,306  00:00:17,057
# 5113       21   0:00:21,104   0:00:22,439
# 5114       21   0:00:22,439   0:00:23,321
# 5115       21   0:00:23,321   0:00:23,763
# 5116       22  00:20:32,356  00:20:33,814
# 5117       22  00:20:39,863  00:20:41,197
# 5118       22  00:20:41,365  00:20:43,824
# 5119       16  00:20:46,161  00:20:49,288
# 5120       16   0:20:49,623   0:20:50,465
# 5121       16   0:20:50,465   0:20:52,099
# 5122       16  00:20:52,209  00:20:53,501
# 5123       16  00:20:54,836  00:20:55,878
# 5124       16  00:20:54,836  00:21:00,758
# 5125       16  00:21:11,311  00:21:13,646
# 5126       16  00:21:13,814  00:21:15,856
# 5127       16  00:21:22,823  00:21:25,032

# %%
train_df[(train_df.Season==4) & (train_df.Episode==24)]
# Out:
# Empty DataFrame
# Columns: [Sr No., Utterance, Speaker, Emotion, Sentiment, Dialogue_ID, Utterance_ID, Season, Episode, StartTime, EndTime]
# Index: []

# %%
train_df.loc[7387, 'Speaker']='the Soap Actor'
train_df[(train_df.Season==9) & (train_df.Episode==11)]
# Out:
#       Sr No.                                          Utterance  \
# 7387    7786                              I'm not your brother.
# 7388    7787  What about my children Drake?! Huh!?  No!! No!...
# 8854    9310      I know you botched that operation on purpose.
# 8855    9311  I can't prove    it yet, but when I do, you'll...
# 8856    9312             I don't care if you    are my brother.
#
#               Speaker  Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  \
# 7387   the Soap Actor  neutral   neutral          785             0       9
# 7388  Phoebe/Waitress    anger  negative          785             1       9
# 8854       Joey/Drake      joy  positive          931             0       9
# 8855       Joey/Drake    anger  negative          931             1       9
# 8856       Joey/Drake  disgust  negative          931             2       9
#
#       Episode     StartTime       EndTime
# 7387       11  00:22:50,786  00:22:52,912
# 7388       11  00:22:53,121  00:23:03,756
# 8854       11  00:22:41,360  00:22:43,694
# 8855       11  00:22:43,862  00:22:48,074
# 8856       11  00:22:48,241  00:22:49,909

# %%
for i in profiles['profiles']:
    print(i['mbti_profile'])
# Out:
# Monica Geller
# Ross Geller
# Chandler Bing
# Phoebe Buffay
# Joey Tribbiani
# Rachel Green
# David “The Scientist Guy“
# Carol Willick
# Emily Waltham
# Gavin Mitchell
# Richard Burke
# Jack Geller
# Roger
# Judy Geller
# Jill Green
# Pete Becker
# Michael “Mike” Hannigan
# Janice Hosenstein
# Mr. Heckles
# Mona
# Gunther
# Charlie Wheeler
# Julie
# Ursula Buffay
# Kathy
# Susan Bunch
# Leonard Green
# Will Colbert
# Amy Green
# Alan
# Chick "Yasmine"
# Dr. Drake Ramoray
# Phoebe Abbott
# Frank Buffay Sr.
# Danny
# Gary
# Emma Geller
# Joanna
# Mr. R. Zelner
# Bonnie
# Susie Moss
# Ugly Naked Guy
# Parker
# Tag Jones
# Ben Geller
# Nora Tyler Bing
# Barry Farber
# Michael Tribbiani
# Mark
# The Gentleman on the Plane
# Sandra Green
# Frank Buffay Jr.
# Alice Knight
# Gloria Tribbiani
# Gina Tribbiani
# Jimmy Costa
# Dina Tribbiani
# Stephen Waltham
# Andrea Waltham
# Alexis Julia "Alex" Garrett
# Janine Lecroix
# Elizabeth Stevens
# Charles Bing (Helena Handbasket)
# Paolo
# Paul Stevens
# Joshua Burgin
# Erica
# Dr. Michael Mitchell
# Fun Bobby
# Mindy Hunter
# Estelle Leonard
# Mr. Treeger
# Doug
# Cecilia Monroe
# Benjamin Hobbart
# Russ
# Eddie Menuek
# Aurora
# Tim
# Tomas
# Duck
# Melissa Warburton
# Kate Miller
# Tommy "The Screamer"
